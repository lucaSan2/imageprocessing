# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow import keras

# %%
from keras.layers import Dense, Flatten, Conv2D, Dropout

# %%
izmir = plt.imread('/content/izmir.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-a96f1741acc8> in <module>
# ----> 1 izmir = plt.imread('/content/izmir.jpg')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2156 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2157 def imread(fname, format=None):
# -> 2158     return matplotlib.image.imread(fname, format)
#    2159
#    2160
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in imread(fname, format)
#    1558                     response = io.BytesIO(response.read())
#    1559                 return imread(response, format=ext)
# -> 1560     with img_open(fname) as image:
#    1561         return (_pil_png_to_float_array(image)
#    1562                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ...

# %%
izmir.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1f17ffa062fe> in <module>
# ----> 1 izmir.shape
#
# NameError: name 'izmir' is not defined

# %%
plt.imshow(izmir)

# %%
izmir2 = izmir.copy()

# %%
izmir2[:,:,1]=0

# %%
izmir2[:,:,2]=0

# %%
plt.imshow(izmir2)

# %%
izmir[200:500, 200:500, :]= [1,0,0]

# %%
plt.imshow(izmir)

# %%
izmir[100:200, 100:200,0]= 1

# %%
izmir[100:200, 100:200,1]= 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-13f92507f047> in <module>
# ----> 1 izmir[100:200, 100:200,1]= 0
#
# NameError: name 'izmir' is not defined

# %%
izmir[100:200, 100:200,2]= 0

# %%
plt.imshow(izmir)

# %%
izmir[200:300,200:300,:] =[1,0,0]

# %%
plt.imshow(izmir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-57935e9b0dc9> in <module>
# ----> 1 plt.imshow(izmir)
#
# NameError: name 'izmir' is not defined

# %%
letters = pd.read_csv('/content/letters.csv')
